# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL="https://ikman.lk/en/ads/sri-lanka/cars/toyota?tree.brand=toyota"

# %%
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36','Accept-Language':'en-US, en;q=0.5'})

# %%
webpage = requests.get(URL, headers=HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link rel="shortcut icon"/>
# <link rel="apple-touch-icon-precomposed"/>
# <link rel="msapplication-TileColor"/>
# <link rel="msapplication-TileImage"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
links = soup.find_all('a', attrs={'class' :'card-link--3ssYv gtm-ad-item'})

# %%
links
# Out:
# [<a class="card-link--3ssYv gtm-ad-item" data-testid="ad-card-link" href="/en/ad/toyota-hilux-hillux-vigo-champ-2012-for-sale-gampaha" title="Toyota Hilux hillux Vigo champ 2012 for sale"><div class="container--2uFyv"><div class="image--2hizm"><div class="featured-member--1CQta"><img alt="Toyota Hilux hillux Vigo champ 2012" class="top-ad--22_qK" data-testid="" loading="lazy" src="https://i.ikman-st.com/toyota-hilux-hillux-vigo-champ-2012-for-sale-gampaha/50712ca0-8f28-490a-a22c-9ab6d9e0c336/160/120/cropped.jpg"/></div></div><div class="content--3JNQz" data-testid="ad-meta"><h2 class="heading--2eONR heading-2--1OnX8 title--3yncE block--3v-Ow">Toyota Hilux hillux Vigo champ 2012</h2><div><div>120,000 km</div><div class="description--2-ez3">Gampaha, Cars</div><div class="price--3SnqI color--t0tGX"><span>Rs 17,300,000</span><span class="spacer--904y9"></span></div></div><div class="top-ad--2SEuR"><a class="card-link--3ssYv" href="/en/promotions" title="Top ad"><div class="icon--3D09z sm
# ...

# %%
link = links[0].get('href')

# %%
product_list = 'https://ikman.lk' + link

# %%
product_list
# Out:
# 'https://ikman.lk/en/ad/toyota-hilux-hillux-vigo-champ-2012-for-sale-gampaha'

# %%
new_webpage = requests.get(product_list, headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

# %%
new_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link rel="shortcut icon"/>
# <link rel="apple-touch-icon-precomposed"/>
# <link rel="msapplication-TileColor"/>
# <link rel="msapplication-TileImage"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
# <title data-rh="">Toyota Hilux hillux Vigo champ 2012 for Sale in Negombo | ikman</title><meta content="telephone=no" data-rh="" name="format-detection"/><meta content="Register 2016
# PH-***
# Multifunction
# Cruise Control
# ABS brake
# Electric seat
# Reverse camera
# 4WD
# Electric canopy
# Hood rack
# 3D carpet
# 3rd owner
# Good condition vehicle" data-rh="" name="description"/><meta content="Toyota Hilux hillux Vigo champ 2012 for Sale in Negombo | ikman" data-rh="" property="og:title"/><meta content="Register 2016
# PH-***
# Multifunction
# Cruise Control
# ABS brake
# ...

# %%
link_elements=new_soup.find_all("a", attrs={"data-testid":'admeta-link'})
link_elements
# Out:
# [<a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/sri-lanka/cars/toyota" title="Toyota Cars"><span>Toyota</span></a>,
#  <a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/sri-lanka/cars/toyota/hilux" title="Toyota Hilux"><span>Hilux</span></a>,
#  <a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/s/040507/sri-lanka/cars/toyota/hilux/2012" title="Toyota Hilux 2012"><span>2012</span></a>,
#  <a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/c/sri-lanka/cars/used/toyota/hilux" title="Used Toyota Hilux 2012"><span>Used</span></a>,
#  <a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/s/0406/sri-lanka/cars/toyota/suv-4x4" title="Toyota SUV / 4x4 Cars"><span>SUV / 4x4</span></a>,
#  <a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/s/0408/sri-lanka/cars/toyota/diesel" title="Toyota Diesel Cars"><span>Diesel</span></a>]

# %%
brand_name
# Out:
# 'Toyota'

# %%
div_elements=new_soup.find_all("div", attrs={"class":'word-break--2nyVq value--1lKHt'})

# %%
div_elements
# Out:
# [<div class="word-break--2nyVq value--1lKHt"><div><a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/sri-lanka/cars/toyota" title="Toyota Cars"><span>Toyota</span></a></div></div>,
#  <div class="word-break--2nyVq value--1lKHt"><div><a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/sri-lanka/cars/toyota/hilux" title="Toyota Hilux"><span>Hilux</span></a></div></div>,
#  <div class="word-break--2nyVq value--1lKHt">hillux Vigo champ</div>,
#  <div class="word-break--2nyVq value--1lKHt"><div><a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/s/040507/sri-lanka/cars/toyota/hilux/2012" title="Toyota Hilux 2012"><span>2012</span></a></div></div>,
#  <div class="word-break--2nyVq value--1lKHt"><div><a class="ad-meta-desktop--1Zyra" data-testid="admeta-link" href="/en/ads/c/sri-lanka/cars/used/toyota/hilux" title="Used Toyota Hilux 2012"><span>Used</span></a></div></div>,
# ...

# %%
 <div class="word-break--2nyVq value--1lKHt">Toyota</div>

# %%
<a class="card-link--3ssYv gtm-ad-item" href="/en/ad/toyota-chr-bruno-2019-for-sale-gampaha" data-testid="ad-card-link" title="Toyota CHR Bruno 2019 for sale"><div class="container--2uFyv"><div class="image--2hizm"><div class="featured-member--1CQta"><img class="normal-ad--1TyjD" src="https://i.ikman-st.com/toyota-chr-bruno-2019-for-sale-gampaha/0a4536a4-3b02-46c5-8aa8-2fc2ca099a95/142/107/cropped.webp" alt="Toyota CHR Bruno 2019" data-testid="" loading="lazy"></div></div><div class="content--3JNQz" data-testid="ad-meta"><h2 class="heading--2eONR heading-2--1OnX8 title--3yncE block--3v-Ow">Toyota CHR Bruno 2019</h2><div><div>35,000 km</div><div class="description--2-ez3">Gampaha, Cars</div><div class="price--3SnqI color--t0tGX"><span>Rs 17,400,000</span><span class="spacer--904y9"></span></div></div><div class="updated-time--1DbCk"><span class="bump-up-time--Z8zuY">1 hour</span><a class="card-link--3ssYv" href="/en/promotions" title="Bump up"><div class="icon--3D09z small--2q8vN"><svg id="bump-up_svg__Layer_1" x="0" y="0" viewBox="0 0 16 16" xmlSpace="preserve" class="svg-wrapper--8ky9e"><style>.bump-up_svg__st1{fill:#ffc800}</style><linearGradient id="bump-up_svg__Path_3_" gradientUnits="userSpaceOnUse" x1="-202.745" y1="307.032" x2="-203.745" y2="307.032" gradientTransform="matrix(-5.2222 0 0 5.2222 -1049.616 -1590.03)"><stop offset="0" stop-color="#d47f34"></stop><stop offset="0.38" stop-color="#e18736"></stop><stop offset="0.8" stop-color="#f59338"></stop></linearGradient><path id="bump-up_svg__Path" d="M10.5 16H9.2v-5.2h5.2v1.3c0 1-.4 2-1.1 2.7S11.5 16 10.5 16z" fill="url(#bump-up_svg__Path_3_)"></path><path id="bump-up_svg__Path_1_" class="bump-up_svg__st1" d="M4.7 6h5.2v10H8.6c-2.1 0-3.9-1.7-3.9-3.9V6z"></path><path id="bump-up_svg__Path_2_" class="bump-up_svg__st1" d="M12.3 4.6L8 .3c-.4-.4-1-.4-1.3 0L2.3 4.7c-.6.6-.1 1.6.7 1.6l8.7-.1c.8 0 1.2-1 .6-1.6z"></path><linearGradient id="bump-up_svg__Rectangle_1_" gradientUnits="userSpaceOnUse" x1="-137.788" y1="189.707" x2="-137.723" y2="190.196" gradientTransform="matrix(5.2222 0 0 -3.4444 726.717 662.247)"><stop offset="0" stop-color="#ffc800"></stop><stop offset="0.43" stop-color="#fec107"></stop><stop offset="1" stop-color="#f9ac31"></stop></linearGradient><path id="bump-up_svg__Rectangle" fill="url(#bump-up_svg__Rectangle_1_)" d="M4.7 6.2h5.2v3.4H4.7z"></path></svg></div></a></div></div></div></a>
